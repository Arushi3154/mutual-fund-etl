# %% [markdown]
# # Mutual Fund Capstone: Advanced Risk & Cohort Analytics

# %% [markdown]
# 1. **Historical 95% VaR / CVaR calculated across all schemes.**
# 2. **SIP Continuity Rate:** 6.37%
# 3. **Flagged At-Risk Investors:** 2762

# %% [markdown]
# ## 1. Value at Risk (VaR) & Tail Risk Summary

# %%
import pandas as pd
var_df = pd.read_csv('var_cvar_report.csv')
var_df.head(10)

# %% [markdown]
# ## 2. Rolling 90-Day Sharpe Ratio Chart
#
# ![](rolling_sharpe_chart.png)

# %% [markdown]
# ## 3. Fund Recommendation Engine Test

# %%
from recommender import recommend_funds
recommend_funds('Moderate')
