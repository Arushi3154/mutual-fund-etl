# %% [markdown]
# # Deliverable D4: Performance & Risk Analytics

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../data/db/bluestock_mf.db")
df_metrics = pd.read_sql("SELECT * FROM calculated_performance_metrics", conn)
print("Calculated Performance Metrics (CAGR, Sharpe, 95% VaR):")
print(df_metrics.head(10))
# Out:
# Calculated Performance Metrics (CAGR, Sharpe, 95% VaR):
#    Amfi Code  CAGR_Annualized  Annualized_Vol  Sharpe_Ratio  Historical_VaR_95
# 0     118632            15.57           16.66          0.54              -1.59
# 1     119092            47.56         2620.04          0.02               0.01
# 2     119551             0.26            8.67         -0.72              -0.10
# 3     120503            16.07             NaN           NaN              -1.46
# 4     120841            17.14           15.40          0.69              -1.42
# 5     125497            24.84           15.18          1.21              -1.51
