# %% [markdown]
# # Deliverable D6: Advanced Analytics & Cohort Analysis

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../data/db/bluestock_mf.db")
df_rec = pd.read_sql("SELECT * FROM recommended_funds", conn)
print("Top Recommended Funds Engine Output:")
print(df_rec.head())
# Out:
# Top Recommended Funds Engine Output:
#    Amfi_Code                                     Scheme_Name   Category  \
# 0   119092.0           Axis Bluechip Fund - Regular - Growth  Large Cap
# 1   125497.0        HDFC Top 100 Fund - Direct Plan - Growth  Large Cap
# 2   120841.0          Kotak Bluechip Fund - Regular - Growth  Large Cap
# 3   120503.0      ICICI Pru Bluechip Fund - Regular - Growth  Large Cap
# 4   118632.0  Nippon India Large Cap Fund - Regular - Growth  Large Cap
#
#    Sharpe_Ratio   CAGR   Score
# 0          0.85  47.56  19.534
# 1          0.96  24.84  10.512
# 2          0.87  17.14   7.378
# 3          0.82  16.07   6.920
# 4          1.00  15.57   6.828
